# %% [markdown]
# # DBX Diff Test Notebook
#
# This notebook is used to test how Databricks shows notebook cell-based diffs.

# %%
message = "Hello from Databricks"
print(message)

# %% [markdown]
# ## Test Section
#
# This markdown cell can be modified to observe markdown diff behavior.

# %%
numbers = [1, 2, 3, 4, 5]
total = sum(numbers)
print("Total:", total)
